# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristinaPhm/ChristinaPhm.github.io/blob/main/education_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_educational_attainment')

# %%
tables

# %%
df=tables[1]

# %%
df
# Out:
#    State or Territory  ... With an Advanced Degree
#    State or Territory  ...                     Pct
# 0             Alabama  ...                  10.04%
# 1              Alaska  ...                  11.69%
# 2             Arizona  ...                  11.35%
# 3            Arkansas  ...                   8.26%
# 4          California  ...                  13.14%
# 5            Colorado  ...                  16.04%
# 6         Connecticut  ...                  17.84%
# 7            Delaware  ...                  13.66%
# 8          Washington  ...                  33.97%
# 9             Florida  ...                  11.44%
# 10            Georgia  ...                  12.59%
# 11             Hawaii  ...                  11.56%
# 12              Idaho  ...                   9.95%
# 13           Illinois  ...                  14.06%
# 14            Indiana  ...                   9.66%
# 15               Iowa  ...                   9.52%
# ...

# %%
df = df.drop('Population over the age of 25', axis=1)
df = df.drop('With an Advanced Degree', axis=1)

# %%
df.columns = df.columns.droplevel(0)

# %%
df
# Out:
#    State or Territory  Population     Pct  Population     Pct
# 0             Alabama     2926985  87.11%      885357  26.35%
# 1              Alaska      452968  93.58%      146157  30.19%
# 2             Arizona     4331542  87.60%     1492158  30.18%
# 3            Arkansas     1781463  87.48%      475367  23.34%
# 4          California    22636359  84.03%     9428484  35.00%
# 5            Colorado     3672723  92.40%     1695602  42.66%
# 6         Connecticut     2264581  90.71%      994548  39.84%
# 7            Delaware      620789  90.32%      228199  33.20%
# 8          Washington      463977  91.85%      301429  59.67%
# 9             Florida    13689867  88.41%     4753637  30.70%
# 10            Georgia     6224197  87.91%     2301568  32.51%
# 11             Hawaii      920690  92.38%      335209  33.63%
# 12              Idaho     1071091  91.47%      336655  28.75%
# 13           Illinois     7812057  89.85%     3108972  35.76%
# ...

# %%
df = df.loc[(df['State or Territory'] == 'New York') | (df['State or Territory'] == 'Maryland') | (df['State or Territory'] == 'Puerto Rico') | (df['State or Territory'] == 'Illinois') | (df['State or Territory'] == 'Mississippi') | (df['State or Territory'] == 'Alabama') | (df['State or Territory'] == 'California')]

# %%
df
# Out:
#    State or Territory  Population     Pct  Population     Pct
# 0             Alabama     2926985  87.11%      885357  26.35%
# 4          California    22636359  84.03%     9428484  35.00%
# 13           Illinois     7812057  89.85%     3108972  35.76%
# 20           Maryland     3781706  90.39%     1710230  40.88%
# 24        Mississippi     1688747  85.30%      441751  22.31%
# 32           New York    11970504  87.60%     5166218  37.81%
# 39        Puerto Rico     1813327  78.78%      626580  27.22%

# %%
df = df.drop(['Population'], axis = 1)

# %%
df.columns = ['State', 'High School Diploma or higher', 'Bachelors Degree or higher']

# %%
df
# Out:
#           State High School Diploma or higher Bachelors Degree or higher
# 0       Alabama                        87.11%                     26.35%
# 4    California                        84.03%                     35.00%
# 13     Illinois                        89.85%                     35.76%
# 20     Maryland                        90.39%                     40.88%
# 24  Mississippi                        85.30%                     22.31%
# 32     New York                        87.60%                     37.81%
# 39  Puerto Rico                        78.78%                     27.22%

# %%
df.to_csv('education_by_state.csv')
